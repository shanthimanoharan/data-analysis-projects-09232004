-- %% [markdown]
-- # SQL Part 3 Studio
--
-- Let's practice your SQL querying skills! For each question, work along in the notebook, adding your query and answering the questions.
--
-- ## The Dataset
--
-- We will be using the Goodbooks-10k dataset from the exercises in the prep work. Feel free reference your previous notebooks.
--
-- 1. The dataset can be found here: [goodbooks-10k](https://www.kaggle.com/zygmunt/goodbooks-10k)
-- 1. You can access `BooksDB` in the LaunchCode server.
--
-- ## Business Issue
--
-- You are an employee at a small independent bookstore and you have been tasked with increasing sales.  You decide to use `BooksDB` to find books and themes to highlight in fun promotions throughout each month and/or season.  We will be starting with March and then you will have a chance to explore another month of your choosing.  We want to come up with a list of promotions to run each month.  If you are looking for ideas, here are some resources on different holidays:
--
-- - [https://www.calendarr.com/united-states/calendar-2022/](https://www.calendarr.com/united-states/calendar-2022/)
-- - [https://www.holidayinsights.com/moreholidays/](https://www.holidayinsights.com/moreholidays/)
--     - Click on a month and it will take you to a more detailed page

-- %% [markdown]
-- ## Part 1:  March - Women's History Month, National Pie Day (3/14), St. Patrick's Day (3/17), Season - Spring

-- %% [markdown]
-- ### Event 1: Women's History Month
--
-- Highlight popular women writers based on ratings from `BooksDB` by writing a query that returns `tag_id`, the number of times each `tag_id` is used and the `tag_name`. Use the `GROUP BY` and `HAVING` clause to narrow your focus and try multiple keywords, such as "woman" and "female".

-- %%
 SELECT t.tag_id,
        t.tag_name,
        bt.goodreads_book_id,
        bt.count 
        FROM BooksDB.dbo.tags as t 
        full JOIN BooksDB.dbo.book_tags as bt 
        ON t.tag_id = bt.tag_id
        GROUP BY t.tag_id,t.tag_name,bt.goodreads_book_id,bt.[count]
        HAVING t.tag_name LIKE '%woman%' OR t.tag_name LIKE '%female%'
        ORDER BY bt.count DESC

SELECT b.authors,
       b.average_rating,
       bt.goodreads_book_id,
       bt.tag_id,
       bt.count
    FROM BooksDB.dbo.books AS b 
    JOIN BooksDB.dbo.book_tags AS bt 
    ON b.book_id = bt.goodreads_book_id
    WHERE bt.tag_id IN (11644,11643)
    ORDER BY b.average_rating DESC
-- Out:
-- (2130 rows affected)
-- (1718 rows affected)
-- Total execution time: 00:00:00.569
-- <table><tr><th>tag_id</th><th>tag_name</th><th>goodreads_book_id</th><th>count</th></tr><tr><td>11644</td><td>female-authors</td><td>38447</td><td>214</td></tr><tr><td>11643</td><td>female-author</td><td>38447</td><td>198</td></tr><tr><td>11643</td><td>female-author</td><td>2</td><td>194</td></tr><tr><td>11644</td><td>female-authors</td><td>10210</td><td>170</td></tr><tr><td>11644</td><td>female-authors</td><td>6185</td><td>158</td></tr><tr><td>11643</td><td>female-author</td><td>10210</td><td>150</td></tr><tr><td>11644</td><td>female-authors</td><td>18490</td><td>146</td></tr><tr><td>11643</td><td>female-author</td><td>18490</td><td>140</td></tr><tr><td>11643</td><td>female-author</td><td>6185</td><td>137</td></tr><tr><td>11644</td><td>female-authors</td><td>48855</td><td>128</td></tr><tr><td>11644</td><td>female-authors</td><td>1934</td><td>120</td></tr><tr><td>11643</td><td>female-author</td><td>3636</td><td>108</td></tr><tr><td>11644</td><td>female-authors</td><td>6149</td><td>106</td></tr><tr><td>11643</td><td>female-author</td><td>20170404</td><td>104</td></tr><tr><td>11643</td><td>female-author</td><td>14935</td><td>103</td></tr><
041</td><td>11644</td><td>5</td></tr><tr><td>Robin Hobb</td><td>4.35</td><td>19288321</td><td>11643</td><td>9</td></tr><tr><td>Erin Hunter</td><td>4.35</td><td>197459</td><td>11643</td><td>4</td></tr><tr><td>V.E. Schwab, Victoria Schwab</td><td>4.33</td><td>20764879</td><td>11643</td><td>29</td></tr><tr><td>Julia Child, Simone Beck, Louisette Bertholle</td><td>4.33</td><td>129650</td><td>11644</td><td>3</td></tr><tr><td>Mary Hoffman, Caroline Binch</td><td>4.33</td><td>765193</td><td>11643</td><td>3</td></tr><tr><td>Enid Blyton</td><td>4.32</td><td>473623</td><td>11644</td><td>3</td></tr><tr><td>Christiane Northrup</td><td>4.32</td><td>131830</td><td>1164 ...

-- %% [markdown]
-- ### Event 2: Choose another event from March/Spring
--
-- Write a query to return authors, titles, ratings, and `tag_id` that you would want to promote during your chosen event.

-- %%
/*SELECT b.authors,
       b.title,
       b.average_rating,
       t.tag_id,
       t.tag_name
FROM BooksDB.dbo.books AS b
JOIN BooksDB.dbo.book_tags AS bt
ON b.book_id = bt.goodreads_book_id
JOIN BooksDB.dbo.tags AS t
ON t.tag_id = bt.tag_id
GROUP BY b.authors,b.title,b.average_rating,t.tag_id,t.tag_name
HAVING t.tag_name LIKE '%spring%'
ORDER BY b.average_rating DESC*/

SELECT tag_id,tag_name
FROM BooksDB.dbo.tags
WHERE tag_name LIKE 'spring%'

SELECT  b.authors,
       b.title,
       b.average_rating,
       bt.tag_id
       FROM BooksDB.dbo.books AS b
       JOIN BooksDB.dbo.book_tags AS bt
       ON b.book_id = bt.goodreads_book_id
       WHERE bt.tag_id IN (28460,28461,28462,28463)
       ORDER BY b.average_rating DESC
-- Out:
-- (4 rows affected)
-- (10 rows affected)
-- Total execution time: 00:00:00.273
-- <table><tr><th>tag_id</th><th>tag_name</th></tr><tr><td>28460</td><td>spring</td></tr><tr><td>28461</td><td>spring-2015</td></tr><tr><td>28462</td><td>spring-tbr-mar1-may31</td></tr><tr><td>28463</td><td>springs</td></tr></table>
-- <table><tr><th>authors</th><th>title</th><th>average_rating</th><th>tag_id</th></tr><tr><td>Barbara Cooney</td><td>Miss Rumphius</td><td>4.45</td><td>28460</td></tr><tr><td>Arnold Lobel</td><td>Frog and Toad All Year (Frog and Toad, #3)</td><td>4.34</td><td>28460</td></tr><tr><td>Robert McCloskey</td><td>Make Way for Ducklings</td><td>4.21</td><td>28460</td></tr><tr><td>P.D. Eastman</td><td>The Best Nest</td><td>4.19</td><td>28460</td></tr><tr><td>Elizabeth Bishop</td><td>The Complete Poems 1927-1979</td><td>4.19</td><td>28461</td></tr><tr><td>Margaret Wise Brown, Clement Hurd</td><td>The Runaway Bunny</td><td>4.14</td><td>28460</td></tr><tr><td>Mary Westmacott, Agatha Christie</td><td>Absent In The Spring</td><td>4.14</td><td>28462</td></tr><tr><td>Ruth Krauss, Crockett Johnson</td><td>The Carrot Seed</td><td>4.07</td><td>28460</td></tr><tr><td>David Shannon</td><td>Duck On A Bike</td><td>4.06</td><td>28460</td></tr><tr><td>Ian Fleming</td><td>Diamonds Are Forever (James Bond, #4)</td><td>3.59</td><td>28463</td></tr></table>

-- %% [markdown]
-- Record your thoughts about why you wrote the query the way you did.

-- %% [markdown]
-- # Part 2: Choose Another Month
--
-- Choose another month and plan at least 2 events / promotions and answer the following questions:
--
-- 1. Which month did you choose? **November**
-- 2. What 2 events / promotions are you highlighting? **Thanksgiving and Veterans day**

-- %% [markdown]
-- # Part 3: Summarize your Work
--
-- For each event write at least one query that joins any two tables in `BooksDB` to support your choice and record you thoughts as to why you used the paticlular query. At least one of your queries needs to include a `HAVING` clause.

-- %%
SELECT tag_id,tag_name
FROM BooksDB.dbo.tags
WHERE tag_name LIKE '%Thanksgiving%'

SELECT  b.authors,
       b.title,
       b.average_rating,
       bt.tag_id
       FROM BooksDB.dbo.books AS b
       JOIN BooksDB.dbo.book_tags AS bt
       ON b.book_id = bt.goodreads_book_id
       WHERE bt.tag_id = 29599
       ORDER BY b.average_rating DESC
-- Out:
-- (1 row affected)
-- (3 rows affected)
-- Total execution time: 00:00:00.172
-- <table><tr><th>tag_id</th><th>tag_name</th></tr><tr><td>29599</td><td>thanksgiving</td></tr></table>
-- <table><tr><th>authors</th><th>title</th><th>average_rating</th><th>tag_id</th></tr><tr><td>Ina Garten, Melanie Acevedo</td><td>The Barefoot Contessa Cookbook</td><td>4.21</td><td>29599</td></tr><tr><td>Ann Voskamp</td><td>One Thousand Gifts: A Dare to Live Fully Right Where You Are</td><td>4.03</td><td>29599</td></tr><tr><td>Nathaniel Philbrick</td><td>Mayflower: A Story of Courage, Community, and War</td><td>3.86</td><td>29599</td></tr></table>

-- %% [markdown]
-- ### Summarize Event 1
--
-- My choice of the month is  November , in the first query i found the tagname which specifies the event "Thanksgiving"  and my second query returns the author name, title,average rating of the tag\_id 29599

-- %%
SELECT tag_id,tag_name
FROM BooksDB.dbo.tags
WHERE tag_name LIKE '%Veterans%'

SELECT  b.authors,
       b.title,
       b.average_rating,
       bt.tag_id
       FROM BooksDB.dbo.books AS b
       JOIN BooksDB.dbo.book_tags AS bt
       ON b.book_id = bt.goodreads_book_id
       GROUP BY b.authors,b.title,b.average_rating,bt.tag_id    
       HAVING bt.tag_id = 31836
       ORDER BY b.average_rating DESC
-- Out:
-- (1 row affected)
-- (8 rows affected)
-- Total execution time: 00:00:00.191
-- <table><tr><th>tag_id</th><th>tag_name</th></tr><tr><td>31836</td><td>veterans</td></tr></table>
-- <table><tr><th>authors</th><th>title</th><th>average_rating</th><th>tag_id</th></tr><tr><td>Eugene B. Sledge, Paul Fussell</td><td>With the Old Breed: At Peleliu and Okinawa</td><td>4.4</td><td>31836</td></tr><tr><td>John Sandford</td><td>Heat Lightning (Virgil Flowers, #2)</td><td>4.16</td><td>31836</td></tr><tr><td>Robert Leckie</td><td>Helmet for My Pillow</td><td>4.13</td><td>31836</td></tr><tr><td>Lee Child</td><td>Running Blind (Jack Reacher, #4)</td><td>4.08</td><td>31836</td></tr><tr><td>Lee Child</td><td>Tripwire  (Jack Reacher, #3)</td><td>4.07</td><td>31836</td></tr><tr><td>Thomas Pynchon</td><td>V.</td><td>3.97</td><td>31836</td></tr><tr><td>Billie Letts</td><td>The Honk and Holler Opening Soon</td><td>3.93</td><td>31836</td></tr><tr><td>Laurie Halse Anderson</td><td>The Impossible Knife of Memory</td><td>3.93</td><td>31836</td></tr></table>

-- %% [markdown]
-- ### Summarize Event 2
--
-- Double-click to edit.
